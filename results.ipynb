# %%
import pickle 
import matplotlib.pyplot as plt
import numpy as np

# %%
loss_generator = pickle.load(
    open('/home/i.sebag/sync/PWGAN/pickle/lg_entropy_affine_o2.pkl', 'rb'))
loss_discriminator = pickle.load(
    open('/home/i.sebag/sync/PWGAN/pickle/ld_entropy_affine_o2.pkl', 'rb'))
mu_q = pickle.load(
    open('/home/i.sebag/sync/PWGAN/pickle/muq_entropy_affine_o2.pkl', 'rb'))
mu_k = pickle.load(
    open('/home/i.sebag/sync/PWGAN/pickle/muk_entropy_affine_o2.pkl', 'rb'))
log_sigma_q = pickle.load(
    open('/home/i.sebag/sync/PWGAN/pickle/logsigmaq_entropy_affine_o2.pkl', 'rb'))
log_sigma_k = pickle.load(
    open('/home/i.sebag/sync/PWGAN/pickle/logsigmak_entropy_affine_o2.pkl', 'rb'))
log_likelihood = pickle.load(open(
    '/home/i.sebag/sync/PWGAN/pickle/log_ikelihood_entropy_affine_o2.pkl', 'rb'))
approx_log_likelihood = pickle.load(open(
    '/home/i.sebag/sync/PWGAN/pickle/approxloglikelihood_entropy_affine_o2.pkl', 'rb'))
approx_log_z = pickle.load(
    open('/home/i.sebag/sync/PWGAN/pickle/approxlogz_entropy_affine_o2.pkl', 'rb'))

# %%
plt.figure()
x = np.linspace(0,100000, 300000)
plt.plot(x, log_likelihood, label = 'log likelihood')
#plt.plot(log_likelihood_no_entropy, label ='log likelihood w/ G has no entropy')
plt.plot(x, approx_log_likelihood, alpha=0.5, label = 'approx log likelihood ')
plt.legend()
plt.xlabel('epochs')
plt.title('log likelihood optimization')
plt.show()

# %%
plt.figure()
plt.plot(loss di, label = 'discriminator loss w/ G has entropy')
plt.plot(lg_entropy, label = 'generator loss w/ G has entropy')
#plt.plot(ld_no_entropy, label = 'discriminator loss w/ G has no entropy')
#plt.plot(lg_no_entropy, label = 'generator w/ G has no entropy')
plt.legend()
plt.title('losses')
plt.show()
