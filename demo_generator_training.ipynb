# %%
import numpy as np
import torch 
from torch import optim, softmax
import torch.nn as nn 
import scipy
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
import tqdm as tqdm
from tqdm import *
import seaborn

# %%
from training import train_generator
from utils import affine_transformation, gaussian_icdf, gmm_2modes_icdf, quadratic, quartic
from plot_helpers import params_recovery, loss_fit

# %% [markdown]
# ## PARAMS : AFFINE; QUADRATIC; ENTROPY

# %%
G = affine_transformation()
D = quadratic()
learning_rate = 1e-4
epochs= 200000
entropy = True

# %%
lg, muq, logsigmaq= train_generator(G, D, learning_rate, epochs, entropy)
# Out:
# 100%|██████████| 200000/200000 [02:17<00:00, 1457.16it/s]

# %%
params_recovery(D, muq, logsigmaq, muk=0, logsigmak=0, training='generator')

# %%
ld=0 
muk=0
logsigmak=0

loss_fit(lg, ld, muq, logsigmaq,  muk, logsigmak, G, D, training='generator')
# Out:
# 100%|██████████| 100000/100000 [00:10<00:00, 9118.30it/s]

# %% [markdown]
# ## PARAMS: AFFINE; QUADRATIC; NO ENTROPY

# %%
G = affine_transformation()
D = quadratic()
learning_rate = 1e-4
epochs= 200000
entropy = False

# %%
lg, muq, logsigmaq= train_generator(G, D, learning_rate, epochs, entropy)
# Out:
# 100%|██████████| 200000/200000 [01:39<00:00, 2003.82it/s]

# %%
params_recovery(D, muq, logsigmaq, muk=0, logsigmak=0, training='generator')

# %%
ld=0 
muk=0
logsigmak=0

loss_fit(lg, ld, muq, logsigmaq,  muk, logsigmak, G, D, training='generator')
# Out:
# 100%|██████████| 100000/100000 [00:11<00:00, 8634.96it/s]

# %% [markdown]
# ## PARAMS: GAUSSIAN ICDF; QUADRATIC; ENTROPY

# %%
G = gaussian_icdf()
D = quadratic(3, 1) #changing initialization to check robustness 
learning_rate = 1e-4
epochs= 200000
entropy = True

# %%
lg, muq, logsigmaq= train_generator(G, D, learning_rate, epochs, entropy)
# Out:
# 100%|██████████| 200000/200000 [01:59<00:00, 1677.76it/s]

# %%
params_recovery(D, muq, logsigmaq, muk=0, logsigmak=0, training='generator')

# %%
ld=0 
muk=0
logsigmak=0

loss_fit(lg, ld, muq, logsigmaq,  muk, logsigmak, G, D, training='generator')
# Out:
# 100%|██████████| 100000/100000 [00:08<00:00, 11366.11it/s]

# %% [markdown]
# ## PARAMS: GAUSSIAN ICDF; QUADRATIC; NO ENTROPY

# %%
G = gaussian_icdf()
D = quadratic(3, 1) #changing initialization to check robustness 
learning_rate = 1e-4
epochs= 200000
entropy = False

# %%
lg, muq, logsigmaq= train_generator(G, D, learning_rate, epochs, entropy)
# Out:
# 100%|██████████| 200000/200000 [01:30<00:00, 2221.94it/s]

# %%
params_recovery(D, muq, logsigmaq, muk=0, logsigmak=0, training='generator')

# %%
ld=0 
muk=0
logsigmak=0

loss_fit(lg, ld, muq, logsigmaq,  muk, logsigmak, G, D, training='generator')
# Out:
# 100%|██████████| 100000/100000 [00:08<00:00, 11445.02it/s]

# %% [markdown]
# ## PARAMS: GMM ICDF; QUARTIC; ENTROPY

# %%
G = gmm_2modes_icdf()
D = quartic()
learning_rate = 1e-3
epochs= 200000
entropy = True

# %%
lg, muq, logsigmaq= train_generator(G, D, learning_rate, epochs, entropy)
# Out:
# 100%|██████████| 200000/200000 [05:42<00:00, 584.25it/s]

# %%
ld=0 
muk=0
logsigmak=0

loss_fit(lg, ld, muq, logsigmaq,  muk, logsigmak, G, D, training='generator')
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]/mnt/nfs/home/i.sebag/PWGAN2/utils.py:62: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   softmax_weights = F.softmax(self.weights)
# 100%|██████████| 100000/100000 [00:20<00:00, 4955.18it/s]

# %% [markdown]
# ## PARAMS: GMM ICDF; QUARTIC; NO ENTROPY

# %%
G = gmm_2modes_icdf()
D = quartic()
learning_rate = 1e-3
epochs= 200000
entropy = False

# %%
lg, muq, logsigmaq= train_generator(G, D, learning_rate, epochs, entropy)
# Out:
#   0%|          | 0/200000 [00:00<?, ?it/s]/mnt/nfs/home/i.sebag/PWGAN2/utils.py:62: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   softmax_weights = F.softmax(self.weights)
# 100%|██████████| 200000/200000 [03:37<00:00, 917.76it/s]

# %%
ld=0 
muk=0
logsigmak=0

loss_fit(lg, ld, muq, logsigmaq,  muk, logsigmak, G, D, training='generator')
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]/mnt/nfs/home/i.sebag/PWGAN2/utils.py:62: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   softmax_weights = F.softmax(self.weights)
# 100%|██████████| 100000/100000 [00:19<00:00, 5020.17it/s]
